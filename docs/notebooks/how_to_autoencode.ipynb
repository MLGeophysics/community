# %% [markdown]
# # Autoencoder sandbox
# ---
# This notebook shows how to autoencode a 30 Hz sine wave with a varying phase.  At the end, the denoising properties of the autoencoder are showcased.

# %%
import numpy as np 
import matplotlib.pyplot as plt




from keras.models import Input, Model, load_model
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import plot_model

from sklearn.cluster import KMeans
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import petname
# Out:
# Using TensorFlow backend.
# /home/trap/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# generate training, test, and validation data
n = 4096
nt = 128
f = 3.0                  # frequency in Hz
t = np.linspace(0,1,nt)  # time stamps in s
x = np.zeros((n,nt))
phase = np.random.uniform(-np.pi, np.pi, size=n)
for i in range(n):
    x[i,:] = np.sin(2*np.pi*f*t + phase[i] )

# %%
# QC generated data is phase shifted but one frequency
for i in range(3):
    plt.plot(t,x[np.random.randint(0,nt-1), :])
plt.show()

# %%
# QC generated phase in [-pi,pi]
plt.hist(phase,bins=31)
plt.show()

# %%
# split into training and test
x_temp, x_test, _, _ = train_test_split(x, x, test_size=0.05)
x_train, x_valid, _, _ = train_test_split(x_temp,
                                          x_temp,
                                          test_size=0.1)
n_train = len(x_train)
n_valid = len(x_valid)
n_test = len(x_test)

# %%
# construct network structure
activation = 'sigmoid'
encoding_dim = 11

# input layer is full time series length nt
inputs = Input((nt,))

# add more hidden layers here
d1 = Dense(encoding_dim, activation='tanh' )(inputs) 

# output layer is same length as input
outputs = Dense(nt, activation='tanh')(d1)

# consolidate to define autoencoder model inputs and outputs
ae = Model(inputs=[inputs], outputs=[outputs])

# specify encoder and decoder model for easy encoding and decoding
encoder_input = Input(shape=(encoding_dim,))
encoder = Model(inputs=inputs, outputs=d1)
decoder_layer = ae.layers[-1]
decoder = Model(inputs=encoder_input, outputs=decoder_layer(encoder_input))

# %%
ae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                1419
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1536
# =================================================================
# Total params: 2,955
# Trainable params: 2,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 1,419
# Trainable params: 1,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 11)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1536
# =================================================================
# Total params: 1,536
# Trainable params: 1,536
# Non-trainable params: 0
# _________________________________________________________________

# %%
# specify opt. strategy
ae.compile(optimizer='adam',
            loss='binary_crossentropy',
            metrics=['mae'])

# %%
# specify training params
batch_size = 16
epochs = 1000
unique_name = petname.name()
model_filename = 'aen_sin_%03dHz_n=%05d_'%(int(f),nt)+unique_name+'.h5'
history_filename = 'results_'+unique_name+'.npz'
earlystopper = EarlyStopping(patience=100, verbose=1)
checkpointer = ModelCheckpoint(model_filename, verbose=1, save_best_only=True)
callbacks = [earlystopper, checkpointer]

# %%
# train
results = ae.fit(x_train,x_train,
                  batch_size = batch_size, 
                  epochs = epochs,
                  validation_data = (x_valid,x_valid),
                  callbacks = callbacks)
# Out:
# Train on 3501 samples, validate on 390 samples
# Epoch 1/1000
# 3501/3501 [==============================] - 1s 156us/step - loss: -2.9629 - mean_absolute_error: 0.4893 - val_loss: -4.2080 - val_mean_absolute_error: 0.3893
#
# Epoch 00001: val_loss improved from inf to -4.20798, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 2/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.3748 - mean_absolute_error: 0.3499 - val_loss: -4.5340 - val_mean_absolute_error: 0.3110
#
# Epoch 00002: val_loss improved from -4.20798 to -4.53398, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 3/1000
# 3501/3501 [==============================] - 0s 134us/step - loss: -4.6346 - mean_absolute_error: 0.2840 - val_loss: -4.7415 - val_mean_absolute_error: 0.2571
#
# Epoch 00003: val_loss improved from -4.53398 to -4.74150, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 4/1000
# 3501/3501 [==============================] - 0s 131us/step - loss: -4.7652 - mean_absolute_error: 0.2426 - val_loss: -4.7979 - val_mean_absolute_error: 0.2215
#
# Epoch 00004: val_loss improved from -4.74150 to -4.79794, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 5/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.8117 - mean_absolute_error: 0.2081 - val_loss: -4.7959 - val_mean_absolute_error: 0.2092
#
# Epoch 00005: val_loss did not improve from -4.79794
# Epoch 6/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.8263 - mean_absolute_error: 0.1885 - val_loss: -4.8406 - val_mean_absolute_error: 0.1758
#
# Epoch 00006: val_loss improved from -4.79794 to -4.84059, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 7/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.8162 - mean_absolute_error: 0.1769 - val_loss: -4.8411 - val_mean_absolute_error: 0.1636
#
# Epoch 00007: val_loss improved from -4.84059 to -4.84108, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 8/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.8512 - mean_absolute_error: 0.1537 - val_loss: -4.8593 - val_mean_absolute_error: 0.1466
#
# Epoch 00008: val_loss improved from -4.84108 to -4.85932, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 9/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.8635 - mean_absolute_error: 0.1402 - val_loss: -4.8702 - val_mean_absolute_error: 0.1339
#
# Epoch 00009: val_loss improved from -4.85932 to -4.87024, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 10/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.8633 - mean_absolute_error: 0.1336 - val_loss: -4.8488 - val_mean_absolute_error: 0.1397
#
# Epoch 00010: val_loss did not improve from -4.87024
# Epoch 11/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.8703 - mean_absolute_error: 0.1253 - val_loss: -4.8788 - val_mean_absolute_error: 0.1182
#
# Epoch 00011: val_loss improved from -4.87024 to -4.87884, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 12/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.8768 - mean_absolute_error: 0.1171 - val_loss: -4.8807 - val_mean_absolute_error: 0.1139
#
# Epoch 00012: val_loss improved from -4.87884 to -4.88074, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 13/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.8822 - mean_absolute_error: 0.1097 - val_loss: -4.8853 - val_mean_absolute_error: 0.1074
#
# Epoch 00013: val_loss improved from -4.88074 to -4.88534, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 14/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.8875 - mean_absolute_error: 0.1027 - val_loss: -4.8907 - val_mean_absolute_error: 0.0995
#
# Epoch 00014: val_loss improved from -4.88534 to -4.89067, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 15/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.8891 - mean_absolute_error: 0.0985 - val_loss: -4.8920 - val_mean_absolute_error: 0.0955
#
# Epoch 00015: val_loss improved from -4.89067 to -4.89202, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 16/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.8850 - mean_absolute_error: 0.0987 - val_loss: -4.8894 - val_mean_absolute_error: 0.0953
#
# Epoch 00016: val_loss did not improve from -4.89202
# Epoch 17/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.8911 - mean_absolute_error: 0.0918 - val_loss: -4.8956 - val_mean_absolute_error: 0.0881
#
# Epoch 00017: val_loss improved from -4.89202 to -4.89557, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 18/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.8955 - mean_absolute_error: 0.0863 - val_loss: -4.8970 - val_mean_absolute_error: 0.0848
#
# Epoch 00018: val_loss improved from -4.89557 to -4.89702, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 19/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.8978 - mean_absolute_error: 0.0828 - val_loss: -4.9001 - val_mean_absolute_error: 0.0806
#
# Epoch 00019: val_loss improved from -4.89702 to -4.90014, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 20/1000
# 3501/3501 [==============================] - 0s 141us/step - loss: -4.8957 - mean_absolute_error: 0.0823 - val_loss: -4.8985 - val_mean_absolute_error: 0.0812
#
# Epoch 00020: val_loss did not improve from -4.90014
# Epoch 21/1000
# 3501/3501 [==============================] - 0s 131us/step - loss: -4.9008 - mean_absolute_error: 0.0772 - val_loss: -4.9027 - val_mean_absolute_error: 0.0754
#
# Epoch 00021: val_loss improved from -4.90014 to -4.90273, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 22/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9001 - mean_absolute_error: 0.0754 - val_loss: -4.9015 - val_mean_absolute_error: 0.0747
#
# Epoch 00022: val_loss did not improve from -4.90273
# Epoch 23/1000
# 3501/3501 [==============================] - 0s 118us/step - loss: -4.8924 - mean_absolute_error: 0.0784 - val_loss: -4.8719 - val_mean_absolute_error: 0.0944
#
# Epoch 00023: val_loss did not improve from -4.90273
# Epoch 24/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.8919 - mean_absolute_error: 0.0812 - val_loss: -4.9027 - val_mean_absolute_error: 0.0726
#
# Epoch 00024: val_loss did not improve from -4.90273
# Epoch 25/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9020 - mean_absolute_error: 0.0707 - val_loss: -4.9050 - val_mean_absolute_error: 0.0681
#
# Epoch 00025: val_loss improved from -4.90273 to -4.90497, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 26/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9046 - mean_absolute_error: 0.0664 - val_loss: -4.9061 - val_mean_absolute_error: 0.0648
#
# Epoch 00026: val_loss improved from -4.90497 to -4.90611, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 27/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9050 - mean_absolute_error: 0.0644 - val_loss: -4.9026 - val_mean_absolute_error: 0.0671
#
# Epoch 00027: val_loss did not improve from -4.90611
# Epoch 28/1000
# 3501/3501 [==============================] - 0s 129us/step - loss: -4.9029 - mean_absolute_error: 0.0646 - val_loss: -4.9067 - val_mean_absolute_error: 0.0616
#
# Epoch 00028: val_loss improved from -4.90611 to -4.90671, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 29/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.8635 - mean_absolute_error: 0.0870 - val_loss: -4.8740 - val_mean_absolute_error: 0.0923
#
# Epoch 00029: val_loss did not improve from -4.90671
# Epoch 30/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.8818 - mean_absolute_error: 0.0869 - val_loss: -4.8778 - val_mean_absolute_error: 0.0878
#
# Epoch 00030: val_loss did not improve from -4.90671
# Epoch 31/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.8879 - mean_absolute_error: 0.0808 - val_loss: -4.8949 - val_mean_absolute_error: 0.0763
#
# Epoch 00031: val_loss did not improve from -4.90671
# Epoch 32/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.8982 - mean_absolute_error: 0.0721 - val_loss: -4.8978 - val_mean_absolute_error: 0.0739
#
# Epoch 00032: val_loss did not improve from -4.90671
# Epoch 33/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9011 - mean_absolute_error: 0.0671 - val_loss: -4.9052 - val_mean_absolute_error: 0.0637
#
# Epoch 00033: val_loss did not improve from -4.90671
# Epoch 34/1000
# 3501/3501 [==============================] - 0s 110us/step - loss: -4.9053 - mean_absolute_error: 0.0614 - val_loss: -4.9071 - val_mean_absolute_error: 0.0600
#
# Epoch 00034: val_loss improved from -4.90671 to -4.90709, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 35/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.9055 - mean_absolute_error: 0.0594 - val_loss: -4.9054 - val_mean_absolute_error: 0.0593
#
# Epoch 00035: val_loss did not improve from -4.90709
# Epoch 36/1000
# 3501/3501 [==============================] - 0s 127us/step - loss: -4.9038 - mean_absolute_error: 0.0599 - val_loss: -4.9079 - val_mean_absolute_error: 0.0570
#
# Epoch 00036: val_loss improved from -4.90709 to -4.90788, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 37/1000
# 3501/3501 [==============================] - 0s 124us/step - loss: -4.9076 - mean_absolute_error: 0.0554 - val_loss: -4.9100 - val_mean_absolute_error: 0.0541
#
# Epoch 00037: val_loss improved from -4.90788 to -4.91004, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 38/1000
# 3501/3501 [==============================] - 0s 110us/step - loss: -4.9074 - mean_absolute_error: 0.0539 - val_loss: -4.9081 - val_mean_absolute_error: 0.0534
#
# Epoch 00038: val_loss did not improve from -4.91004
# Epoch 39/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9089 - mean_absolute_error: 0.0513 - val_loss: -4.9114 - val_mean_absolute_error: 0.0497
#
# Epoch 00039: val_loss improved from -4.91004 to -4.91140, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 40/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9108 - mean_absolute_error: 0.0482 - val_loss: -4.9120 - val_mean_absolute_error: 0.0476
#
# Epoch 00040: val_loss improved from -4.91140 to -4.91205, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 41/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9084 - mean_absolute_error: 0.0492 - val_loss: -4.8899 - val_mean_absolute_error: 0.0666
#
# Epoch 00041: val_loss did not improve from -4.91205
# Epoch 42/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.8905 - mean_absolute_error: 0.0645 - val_loss: -4.9066 - val_mean_absolute_error: 0.0547
#
# Epoch 00042: val_loss did not improve from -4.91205
# Epoch 43/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9042 - mean_absolute_error: 0.0540 - val_loss: -4.9084 - val_mean_absolute_error: 0.0506
#
# Epoch 00043: val_loss did not improve from -4.91205
# Epoch 44/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.8819 - mean_absolute_error: 0.0736 - val_loss: -4.8961 - val_mean_absolute_error: 0.0698
#
# Epoch 00044: val_loss did not improve from -4.91205
# Epoch 45/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9005 - mean_absolute_error: 0.0637 - val_loss: -4.9057 - val_mean_absolute_error: 0.0583
#
# Epoch 00045: val_loss did not improve from -4.91205
# Epoch 46/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9049 - mean_absolute_error: 0.0561 - val_loss: -4.9072 - val_mean_absolute_error: 0.0540
#
# Epoch 00046: val_loss did not improve from -4.91205
# Epoch 47/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9024 - mean_absolute_error: 0.0558 - val_loss: -4.8986 - val_mean_absolute_error: 0.0620
#
# Epoch 00047: val_loss did not improve from -4.91205
# Epoch 48/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.8908 - mean_absolute_error: 0.0688 - val_loss: -4.9016 - val_mean_absolute_error: 0.0603
#
# Epoch 00048: val_loss did not improve from -4.91205
# Epoch 49/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9022 - mean_absolute_error: 0.0556 - val_loss: -4.9076 - val_mean_absolute_error: 0.0503
#
# Epoch 00049: val_loss did not improve from -4.91205
# Epoch 50/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9065 - mean_absolute_error: 0.0492 - val_loss: -4.9099 - val_mean_absolute_error: 0.0465
#
# Epoch 00050: val_loss did not improve from -4.91205
# Epoch 51/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9079 - mean_absolute_error: 0.0466 - val_loss: -4.9108 - val_mean_absolute_error: 0.0440
#
# Epoch 00051: val_loss did not improve from -4.91205
# Epoch 52/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9098 - mean_absolute_error: 0.0434 - val_loss: -4.8993 - val_mean_absolute_error: 0.0545
#
# Epoch 00052: val_loss did not improve from -4.91205
# Epoch 53/1000
# 3501/3501 [==============================] - 0s 103us/step - loss: -4.9077 - mean_absolute_error: 0.0446 - val_loss: -4.9120 - val_mean_absolute_error: 0.0407
#
# Epoch 00053: val_loss did not improve from -4.91205
# Epoch 54/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9073 - mean_absolute_error: 0.0433 - val_loss: -4.8722 - val_mean_absolute_error: 0.0772
#
# Epoch 00054: val_loss did not improve from -4.91205
# Epoch 55/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9055 - mean_absolute_error: 0.0477 - val_loss: -4.9106 - val_mean_absolute_error: 0.0424
#
# Epoch 00055: val_loss did not improve from -4.91205
# Epoch 56/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9106 - mean_absolute_error: 0.0396 - val_loss: -4.9124 - val_mean_absolute_error: 0.0395
#
# Epoch 00056: val_loss improved from -4.91205 to -4.91237, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 57/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9119 - mean_absolute_error: 0.0375 - val_loss: -4.9139 - val_mean_absolute_error: 0.0359
#
# Epoch 00057: val_loss improved from -4.91237 to -4.91393, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 58/1000
# 3501/3501 [==============================] - 0s 128us/step - loss: -4.9132 - mean_absolute_error: 0.0355 - val_loss: -4.9134 - val_mean_absolute_error: 0.0353
#
# Epoch 00058: val_loss did not improve from -4.91393
# Epoch 59/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.9101 - mean_absolute_error: 0.0385 - val_loss: -4.8962 - val_mean_absolute_error: 0.0582
#
# Epoch 00059: val_loss did not improve from -4.91393
# Epoch 60/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9084 - mean_absolute_error: 0.0403 - val_loss: -4.9139 - val_mean_absolute_error: 0.0348
#
# Epoch 00060: val_loss did not improve from -4.91393
# Epoch 61/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9111 - mean_absolute_error: 0.0359 - val_loss: -4.9149 - val_mean_absolute_error: 0.0328
#
# Epoch 00061: val_loss improved from -4.91393 to -4.91488, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 62/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9123 - mean_absolute_error: 0.0347 - val_loss: -4.9141 - val_mean_absolute_error: 0.0335
#
# Epoch 00062: val_loss did not improve from -4.91488
# Epoch 63/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9123 - mean_absolute_error: 0.0339 - val_loss: -4.9142 - val_mean_absolute_error: 0.0340
#
# Epoch 00063: val_loss did not improve from -4.91488
# Epoch 64/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9141 - mean_absolute_error: 0.0321 - val_loss: -4.9159 - val_mean_absolute_error: 0.0304
#
# Epoch 00064: val_loss improved from -4.91488 to -4.91593, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 65/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9156 - mean_absolute_error: 0.0295 - val_loss: -4.9172 - val_mean_absolute_error: 0.0287
#
# Epoch 00065: val_loss improved from -4.91593 to -4.91721, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 66/1000
# 3501/3501 [==============================] - 0s 129us/step - loss: -4.9146 - mean_absolute_error: 0.0302 - val_loss: -4.9122 - val_mean_absolute_error: 0.0373
#
# Epoch 00066: val_loss did not improve from -4.91721
# Epoch 67/1000
# 3501/3501 [==============================] - 0s 136us/step - loss: -4.9104 - mean_absolute_error: 0.0340 - val_loss: -4.9134 - val_mean_absolute_error: 0.0309
#
# Epoch 00067: val_loss did not improve from -4.91721
# Epoch 68/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.9142 - mean_absolute_error: 0.0303 - val_loss: -4.9175 - val_mean_absolute_error: 0.0280
#
# Epoch 00068: val_loss improved from -4.91721 to -4.91746, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 69/1000
# 3501/3501 [==============================] - 0s 138us/step - loss: -4.9158 - mean_absolute_error: 0.0277 - val_loss: -4.9175 - val_mean_absolute_error: 0.0266
#
# Epoch 00069: val_loss improved from -4.91746 to -4.91752, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 70/1000
# 3501/3501 [==============================] - 1s 147us/step - loss: -4.9153 - mean_absolute_error: 0.0280 - val_loss: -4.9158 - val_mean_absolute_error: 0.0282
#
# Epoch 00070: val_loss did not improve from -4.91752
# Epoch 71/1000
# 3501/3501 [==============================] - 1s 204us/step - loss: -4.9102 - mean_absolute_error: 0.0344 - val_loss: -4.9089 - val_mean_absolute_error: 0.0368
#
# Epoch 00071: val_loss did not improve from -4.91752
# Epoch 72/1000
# 3501/3501 [==============================] - 1s 187us/step - loss: -4.9059 - mean_absolute_error: 0.0400 - val_loss: -4.9054 - val_mean_absolute_error: 0.0428
#
# Epoch 00072: val_loss did not improve from -4.91752
# Epoch 73/1000
# 3501/3501 [==============================] - 1s 185us/step - loss: -4.9023 - mean_absolute_error: 0.0410 - val_loss: -4.9077 - val_mean_absolute_error: 0.0377
#
# Epoch 00073: val_loss did not improve from -4.91752
# Epoch 74/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9023 - mean_absolute_error: 0.0417 - val_loss: -4.9034 - val_mean_absolute_error: 0.0482
#
# Epoch 00074: val_loss did not improve from -4.91752
# Epoch 75/1000
# 3501/3501 [==============================] - 0s 137us/step - loss: -4.9044 - mean_absolute_error: 0.0485 - val_loss: -4.9080 - val_mean_absolute_error: 0.0441
#
# Epoch 00075: val_loss did not improve from -4.91752
# Epoch 76/1000
# 3501/3501 [==============================] - 0s 137us/step - loss: -4.9085 - mean_absolute_error: 0.0407 - val_loss: -4.9103 - val_mean_absolute_error: 0.0399
#
# Epoch 00076: val_loss did not improve from -4.91752
# Epoch 77/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9099 - mean_absolute_error: 0.0376 - val_loss: -4.9117 - val_mean_absolute_error: 0.0367
#
# Epoch 00077: val_loss did not improve from -4.91752
# Epoch 78/1000
# 3501/3501 [==============================] - 0s 128us/step - loss: -4.9130 - mean_absolute_error: 0.0338 - val_loss: -4.9152 - val_mean_absolute_error: 0.0324
#
# Epoch 00078: val_loss did not improve from -4.91752
# Epoch 79/1000
# 3501/3501 [==============================] - 0s 127us/step - loss: -4.9124 - mean_absolute_error: 0.0346 - val_loss: -4.9090 - val_mean_absolute_error: 0.0402
#
# Epoch 00079: val_loss did not improve from -4.91752
# Epoch 80/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.9080 - mean_absolute_error: 0.0406 - val_loss: -4.9118 - val_mean_absolute_error: 0.0372
#
# Epoch 00080: val_loss did not improve from -4.91752
# Epoch 81/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9121 - mean_absolute_error: 0.0338 - val_loss: -4.9152 - val_mean_absolute_error: 0.0310
#
# Epoch 00081: val_loss did not improve from -4.91752
# Epoch 82/1000
# 3501/3501 [==============================] - 0s 128us/step - loss: -4.9113 - mean_absolute_error: 0.0344 - val_loss: -4.9127 - val_mean_absolute_error: 0.0327
#
# Epoch 00082: val_loss did not improve from -4.91752
# Epoch 83/1000
# 3501/3501 [==============================] - 0s 127us/step - loss: -4.9143 - mean_absolute_error: 0.0297 - val_loss: -4.9158 - val_mean_absolute_error: 0.0290
#
# Epoch 00083: val_loss did not improve from -4.91752
# Epoch 84/1000
# 3501/3501 [==============================] - 0s 127us/step - loss: -4.9152 - mean_absolute_error: 0.0281 - val_loss: -4.9164 - val_mean_absolute_error: 0.0274
#
# Epoch 00084: val_loss did not improve from -4.91752
# Epoch 85/1000
# 3501/3501 [==============================] - 0s 130us/step - loss: -4.9082 - mean_absolute_error: 0.0375 - val_loss: -4.9057 - val_mean_absolute_error: 0.0449
#
# Epoch 00085: val_loss did not improve from -4.91752
# Epoch 86/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9101 - mean_absolute_error: 0.0358 - val_loss: -4.9152 - val_mean_absolute_error: 0.0313
#
# Epoch 00086: val_loss did not improve from -4.91752
# Epoch 87/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9144 - mean_absolute_error: 0.0306 - val_loss: -4.9166 - val_mean_absolute_error: 0.0286
#
# Epoch 00087: val_loss did not improve from -4.91752
# Epoch 88/1000
# 3501/3501 [==============================] - 1s 145us/step - loss: -4.9145 - mean_absolute_error: 0.0291 - val_loss: -4.9136 - val_mean_absolute_error: 0.0297
#
# Epoch 00088: val_loss did not improve from -4.91752
# Epoch 89/1000
# 3501/3501 [==============================] - 1s 148us/step - loss: -4.9065 - mean_absolute_error: 0.0387 - val_loss: -4.9133 - val_mean_absolute_error: 0.0315
#
# Epoch 00089: val_loss did not improve from -4.91752
# Epoch 90/1000
# 3501/3501 [==============================] - 1s 153us/step - loss: -4.9114 - mean_absolute_error: 0.0328 - val_loss: -4.9124 - val_mean_absolute_error: 0.0355
#
# Epoch 00090: val_loss did not improve from -4.91752
# Epoch 91/1000
# 3501/3501 [==============================] - 1s 145us/step - loss: -4.9134 - mean_absolute_error: 0.0298 - val_loss: -4.9167 - val_mean_absolute_error: 0.0269
#
# Epoch 00091: val_loss did not improve from -4.91752
# Epoch 92/1000
# 3501/3501 [==============================] - 1s 146us/step - loss: -4.9069 - mean_absolute_error: 0.0348 - val_loss: -4.9122 - val_mean_absolute_error: 0.0328
#
# Epoch 00092: val_loss did not improve from -4.91752
# Epoch 93/1000
# 3501/3501 [==============================] - 0s 131us/step - loss: -4.9044 - mean_absolute_error: 0.0394 - val_loss: -4.8989 - val_mean_absolute_error: 0.0510
#
# Epoch 00093: val_loss did not improve from -4.91752
# Epoch 94/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.8893 - mean_absolute_error: 0.0611 - val_loss: -4.8646 - val_mean_absolute_error: 0.0795
#
# Epoch 00094: val_loss did not improve from -4.91752
# Epoch 95/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.8905 - mean_absolute_error: 0.0699 - val_loss: -4.8998 - val_mean_absolute_error: 0.0628
#
# Epoch 00095: val_loss did not improve from -4.91752
# Epoch 96/1000
# 3501/3501 [==============================] - 0s 124us/step - loss: -4.8928 - mean_absolute_error: 0.0660 - val_loss: -4.8908 - val_mean_absolute_error: 0.0683
#
# Epoch 00096: val_loss did not improve from -4.91752
# Epoch 97/1000
# 3501/3501 [==============================] - 0s 124us/step - loss: -4.8884 - mean_absolute_error: 0.0684 - val_loss: -4.8914 - val_mean_absolute_error: 0.0673
#
# Epoch 00097: val_loss did not improve from -4.91752
# Epoch 98/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.8981 - mean_absolute_error: 0.0609 - val_loss: -4.9023 - val_mean_absolute_error: 0.0582
#
# Epoch 00098: val_loss did not improve from -4.91752
# Epoch 99/1000
# 3501/3501 [==============================] - 0s 103us/step - loss: -4.9010 - mean_absolute_error: 0.0575 - val_loss: -4.9062 - val_mean_absolute_error: 0.0502
#
# Epoch 00099: val_loss did not improve from -4.91752
# Epoch 100/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9062 - mean_absolute_error: 0.0483 - val_loss: -4.9069 - val_mean_absolute_error: 0.0473
#
# Epoch 00100: val_loss did not improve from -4.91752
# Epoch 101/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9073 - mean_absolute_error: 0.0444 - val_loss: -4.9101 - val_mean_absolute_error: 0.0417
#
# Epoch 00101: val_loss did not improve from -4.91752
# Epoch 102/1000
# 3501/3501 [==============================] - 0s 118us/step - loss: -4.9067 - mean_absolute_error: 0.0437 - val_loss: -4.9082 - val_mean_absolute_error: 0.0444
#
# Epoch 00102: val_loss did not improve from -4.91752
# Epoch 103/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9095 - mean_absolute_error: 0.0412 - val_loss: -4.9106 - val_mean_absolute_error: 0.0387
#
# Epoch 00103: val_loss did not improve from -4.91752
# Epoch 104/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9117 - mean_absolute_error: 0.0372 - val_loss: -4.9124 - val_mean_absolute_error: 0.0386
#
# Epoch 00104: val_loss did not improve from -4.91752
# Epoch 105/1000
# 3501/3501 [==============================] - 0s 113us/step - loss: -4.9099 - mean_absolute_error: 0.0381 - val_loss: -4.9095 - val_mean_absolute_error: 0.0390
#
# Epoch 00105: val_loss did not improve from -4.91752
# Epoch 106/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.9082 - mean_absolute_error: 0.0405 - val_loss: -4.9105 - val_mean_absolute_error: 0.0408
#
# Epoch 00106: val_loss did not improve from -4.91752
# Epoch 107/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9126 - mean_absolute_error: 0.0361 - val_loss: -4.9145 - val_mean_absolute_error: 0.0334
#
# Epoch 00107: val_loss did not improve from -4.91752
# Epoch 108/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9134 - mean_absolute_error: 0.0324 - val_loss: -4.9151 - val_mean_absolute_error: 0.0313
#
# Epoch 00108: val_loss did not improve from -4.91752
# Epoch 109/1000
# 3501/3501 [==============================] - 0s 118us/step - loss: -4.9147 - mean_absolute_error: 0.0313 - val_loss: -4.9148 - val_mean_absolute_error: 0.0313
#
# Epoch 00109: val_loss did not improve from -4.91752
# Epoch 110/1000
# 3501/3501 [==============================] - 0s 122us/step - loss: -4.9151 - mean_absolute_error: 0.0299 - val_loss: -4.9149 - val_mean_absolute_error: 0.0309
#
# Epoch 00110: val_loss did not improve from -4.91752
# Epoch 111/1000
# 3501/3501 [==============================] - 0s 134us/step - loss: -4.9134 - mean_absolute_error: 0.0310 - val_loss: -4.9157 - val_mean_absolute_error: 0.0289
#
# Epoch 00111: val_loss did not improve from -4.91752
# Epoch 112/1000
# 3501/3501 [==============================] - 0s 138us/step - loss: -4.9091 - mean_absolute_error: 0.0376 - val_loss: -4.9122 - val_mean_absolute_error: 0.0375
#
# Epoch 00112: val_loss did not improve from -4.91752
# Epoch 113/1000
# 3501/3501 [==============================] - 0s 136us/step - loss: -4.9072 - mean_absolute_error: 0.0402 - val_loss: -4.9084 - val_mean_absolute_error: 0.0436
#
# Epoch 00113: val_loss did not improve from -4.91752
# Epoch 114/1000
# 3501/3501 [==============================] - 0s 138us/step - loss: -4.9026 - mean_absolute_error: 0.0473 - val_loss: -4.9088 - val_mean_absolute_error: 0.0417
#
# Epoch 00114: val_loss did not improve from -4.91752
# Epoch 115/1000
# 3501/3501 [==============================] - 0s 134us/step - loss: -4.9100 - mean_absolute_error: 0.0385 - val_loss: -4.9123 - val_mean_absolute_error: 0.0366
#
# Epoch 00115: val_loss did not improve from -4.91752
# Epoch 116/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9112 - mean_absolute_error: 0.0362 - val_loss: -4.9091 - val_mean_absolute_error: 0.0397
#
# Epoch 00116: val_loss did not improve from -4.91752
# Epoch 117/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9117 - mean_absolute_error: 0.0351 - val_loss: -4.9140 - val_mean_absolute_error: 0.0331
#
# Epoch 00117: val_loss did not improve from -4.91752
# Epoch 118/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9133 - mean_absolute_error: 0.0328 - val_loss: -4.9129 - val_mean_absolute_error: 0.0326
#
# Epoch 00118: val_loss did not improve from -4.91752
# Epoch 119/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9133 - mean_absolute_error: 0.0321 - val_loss: -4.9157 - val_mean_absolute_error: 0.0305
#
# Epoch 00119: val_loss did not improve from -4.91752
# Epoch 120/1000
# 3501/3501 [==============================] - 0s 113us/step - loss: -4.9150 - mean_absolute_error: 0.0295 - val_loss: -4.9164 - val_mean_absolute_error: 0.0288
#
# Epoch 00120: val_loss did not improve from -4.91752
# Epoch 121/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9154 - mean_absolute_error: 0.0277 - val_loss: -4.9171 - val_mean_absolute_error: 0.0266
#
# Epoch 00121: val_loss did not improve from -4.91752
# Epoch 122/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9141 - mean_absolute_error: 0.0286 - val_loss: -4.9158 - val_mean_absolute_error: 0.0281
#
# Epoch 00122: val_loss did not improve from -4.91752
# Epoch 123/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9088 - mean_absolute_error: 0.0355 - val_loss: -4.9142 - val_mean_absolute_error: 0.0307
#
# Epoch 00123: val_loss did not improve from -4.91752
# Epoch 124/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9139 - mean_absolute_error: 0.0296 - val_loss: -4.9153 - val_mean_absolute_error: 0.0291
#
# Epoch 00124: val_loss did not improve from -4.91752
# Epoch 125/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9121 - mean_absolute_error: 0.0305 - val_loss: -4.9148 - val_mean_absolute_error: 0.0279
#
# Epoch 00125: val_loss did not improve from -4.91752
# Epoch 126/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9099 - mean_absolute_error: 0.0327 - val_loss: -4.9041 - val_mean_absolute_error: 0.0434
#
# Epoch 00126: val_loss did not improve from -4.91752
# Epoch 127/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9097 - mean_absolute_error: 0.0338 - val_loss: -4.9151 - val_mean_absolute_error: 0.0281
#
# Epoch 00127: val_loss did not improve from -4.91752
# Epoch 128/1000
# 3501/3501 [==============================] - 0s 110us/step - loss: -4.9125 - mean_absolute_error: 0.0293 - val_loss: -4.9138 - val_mean_absolute_error: 0.0293
#
# Epoch 00128: val_loss did not improve from -4.91752
# Epoch 129/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9150 - mean_absolute_error: 0.0263 - val_loss: -4.9172 - val_mean_absolute_error: 0.0242
#
# Epoch 00129: val_loss did not improve from -4.91752
# Epoch 130/1000
# 3501/3501 [==============================] - 0s 113us/step - loss: -4.9069 - mean_absolute_error: 0.0405 - val_loss: -4.9120 - val_mean_absolute_error: 0.0375
#
# Epoch 00130: val_loss did not improve from -4.91752
# Epoch 131/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9115 - mean_absolute_error: 0.0364 - val_loss: -4.9136 - val_mean_absolute_error: 0.0347
#
# Epoch 00131: val_loss did not improve from -4.91752
# Epoch 132/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9130 - mean_absolute_error: 0.0332 - val_loss: -4.9135 - val_mean_absolute_error: 0.0329
#
# Epoch 00132: val_loss did not improve from -4.91752
# Epoch 133/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9110 - mean_absolute_error: 0.0342 - val_loss: -4.9082 - val_mean_absolute_error: 0.0419
#
# Epoch 00133: val_loss did not improve from -4.91752
# Epoch 134/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9090 - mean_absolute_error: 0.0387 - val_loss: -4.9123 - val_mean_absolute_error: 0.0377
#
# Epoch 00134: val_loss did not improve from -4.91752
# Epoch 135/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.9085 - mean_absolute_error: 0.0368 - val_loss: -4.9091 - val_mean_absolute_error: 0.0346
#
# Epoch 00135: val_loss did not improve from -4.91752
# Epoch 136/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.9040 - mean_absolute_error: 0.0411 - val_loss: -4.9082 - val_mean_absolute_error: 0.0421
#
# Epoch 00136: val_loss did not improve from -4.91752
# Epoch 137/1000
# 3501/3501 [==============================] - 0s 131us/step - loss: -4.9100 - mean_absolute_error: 0.0378 - val_loss: -4.9116 - val_mean_absolute_error: 0.0369
#
# Epoch 00137: val_loss did not improve from -4.91752
# Epoch 138/1000
# 3501/3501 [==============================] - 0s 128us/step - loss: -4.9089 - mean_absolute_error: 0.0359 - val_loss: -4.9122 - val_mean_absolute_error: 0.0338
#
# Epoch 00138: val_loss did not improve from -4.91752
# Epoch 139/1000
# 3501/3501 [==============================] - 0s 132us/step - loss: -4.9081 - mean_absolute_error: 0.0369 - val_loss: -4.9132 - val_mean_absolute_error: 0.0359
#
# Epoch 00139: val_loss did not improve from -4.91752
# Epoch 140/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9107 - mean_absolute_error: 0.0340 - val_loss: -4.9135 - val_mean_absolute_error: 0.0326
#
# Epoch 00140: val_loss did not improve from -4.91752
# Epoch 141/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.9111 - mean_absolute_error: 0.0341 - val_loss: -4.9074 - val_mean_absolute_error: 0.0395
#
# Epoch 00141: val_loss did not improve from -4.91752
# Epoch 142/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9086 - mean_absolute_error: 0.0350 - val_loss: -4.9122 - val_mean_absolute_error: 0.0320
#
# Epoch 00142: val_loss did not improve from -4.91752
# Epoch 143/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9120 - mean_absolute_error: 0.0307 - val_loss: -4.9131 - val_mean_absolute_error: 0.0322
#
# Epoch 00143: val_loss did not improve from -4.91752
# Epoch 144/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9136 - mean_absolute_error: 0.0283 - val_loss: -4.9160 - val_mean_absolute_error: 0.0267
#
# Epoch 00144: val_loss did not improve from -4.91752
# Epoch 145/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9135 - mean_absolute_error: 0.0279 - val_loss: -4.9154 - val_mean_absolute_error: 0.0267
#
# Epoch 00145: val_loss did not improve from -4.91752
# Epoch 146/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9107 - mean_absolute_error: 0.0326 - val_loss: -4.9091 - val_mean_absolute_error: 0.0403
#
# Epoch 00146: val_loss did not improve from -4.91752
# Epoch 147/1000
# 3501/3501 [==============================] - 0s 101us/step - loss: -4.9117 - mean_absolute_error: 0.0337 - val_loss: -4.9142 - val_mean_absolute_error: 0.0282
#
# Epoch 00147: val_loss did not improve from -4.91752
# Epoch 148/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9076 - mean_absolute_error: 0.0359 - val_loss: -4.9125 - val_mean_absolute_error: 0.0310
#
# Epoch 00148: val_loss did not improve from -4.91752
# Epoch 149/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9103 - mean_absolute_error: 0.0335 - val_loss: -4.9133 - val_mean_absolute_error: 0.0325
#
# Epoch 00149: val_loss did not improve from -4.91752
# Epoch 150/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9102 - mean_absolute_error: 0.0313 - val_loss: -4.9070 - val_mean_absolute_error: 0.0390
#
# Epoch 00150: val_loss did not improve from -4.91752
# Epoch 151/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.8986 - mean_absolute_error: 0.0479 - val_loss: -4.9083 - val_mean_absolute_error: 0.0434
#
# Epoch 00151: val_loss did not improve from -4.91752
# Epoch 152/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9103 - mean_absolute_error: 0.0367 - val_loss: -4.9126 - val_mean_absolute_error: 0.0336
#
# Epoch 00152: val_loss did not improve from -4.91752
# Epoch 153/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9114 - mean_absolute_error: 0.0347 - val_loss: -4.9127 - val_mean_absolute_error: 0.0337
#
# Epoch 00153: val_loss did not improve from -4.91752
# Epoch 154/1000
# 3501/3501 [==============================] - 0s 103us/step - loss: -4.9135 - mean_absolute_error: 0.0302 - val_loss: -4.9171 - val_mean_absolute_error: 0.0266
#
# Epoch 00154: val_loss did not improve from -4.91752
# Epoch 155/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9098 - mean_absolute_error: 0.0362 - val_loss: -4.9095 - val_mean_absolute_error: 0.0382
#
# Epoch 00155: val_loss did not improve from -4.91752
# Epoch 156/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9114 - mean_absolute_error: 0.0326 - val_loss: -4.9122 - val_mean_absolute_error: 0.0303
#
# Epoch 00156: val_loss did not improve from -4.91752
# Epoch 157/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9086 - mean_absolute_error: 0.0356 - val_loss: -4.9125 - val_mean_absolute_error: 0.0334
#
# Epoch 00157: val_loss did not improve from -4.91752
# Epoch 158/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9111 - mean_absolute_error: 0.0326 - val_loss: -4.9150 - val_mean_absolute_error: 0.0295
#
# Epoch 00158: val_loss did not improve from -4.91752
# Epoch 159/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9108 - mean_absolute_error: 0.0321 - val_loss: -4.9101 - val_mean_absolute_error: 0.0374
#
# Epoch 00159: val_loss did not improve from -4.91752
# Epoch 160/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.9105 - mean_absolute_error: 0.0360 - val_loss: -4.9136 - val_mean_absolute_error: 0.0313
#
# Epoch 00160: val_loss did not improve from -4.91752
# Epoch 161/1000
# 3501/3501 [==============================] - 0s 113us/step - loss: -4.9141 - mean_absolute_error: 0.0265 - val_loss: -4.9165 - val_mean_absolute_error: 0.0240
#
# Epoch 00161: val_loss did not improve from -4.91752
# Epoch 162/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9108 - mean_absolute_error: 0.0293 - val_loss: -4.9135 - val_mean_absolute_error: 0.0277
#
# Epoch 00162: val_loss did not improve from -4.91752
# Epoch 163/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9141 - mean_absolute_error: 0.0247 - val_loss: -4.9164 - val_mean_absolute_error: 0.0222
#
# Epoch 00163: val_loss did not improve from -4.91752
# Epoch 164/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9162 - mean_absolute_error: 0.0219 - val_loss: -4.9170 - val_mean_absolute_error: 0.0221
#
# Epoch 00164: val_loss did not improve from -4.91752
# Epoch 165/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.9151 - mean_absolute_error: 0.0255 - val_loss: -4.9179 - val_mean_absolute_error: 0.0245
#
# Epoch 00165: val_loss improved from -4.91752 to -4.91789, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 166/1000
# 3501/3501 [==============================] - 0s 124us/step - loss: -4.9174 - mean_absolute_error: 0.0219 - val_loss: -4.9189 - val_mean_absolute_error: 0.0202
#
# Epoch 00166: val_loss improved from -4.91789 to -4.91893, saving model to aen_sin_003Hz_n=00128_aphid.h5
# Epoch 167/1000
# 3501/3501 [==============================] - 0s 134us/step - loss: -4.9181 - mean_absolute_error: 0.0189 - val_loss: -4.9179 - val_mean_absolute_error: 0.0208
#
# Epoch 00167: val_loss did not improve from -4.91893
# Epoch 168/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9173 - mean_absolute_error: 0.0196 - val_loss: -4.9158 - val_mean_absolute_error: 0.0208
#
# Epoch 00168: val_loss did not improve from -4.91893
# Epoch 169/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9144 - mean_absolute_error: 0.0235 - val_loss: -4.9152 - val_mean_absolute_error: 0.0212
#
# Epoch 00169: val_loss did not improve from -4.91893
# Epoch 170/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9084 - mean_absolute_error: 0.0333 - val_loss: -4.9107 - val_mean_absolute_error: 0.0352
#
# Epoch 00170: val_loss did not improve from -4.91893
# Epoch 171/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9123 - mean_absolute_error: 0.0298 - val_loss: -4.9146 - val_mean_absolute_error: 0.0263
#
# Epoch 00171: val_loss did not improve from -4.91893
# Epoch 172/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9091 - mean_absolute_error: 0.0291 - val_loss: -4.8707 - val_mean_absolute_error: 0.0594
#
# Epoch 00172: val_loss did not improve from -4.91893
# Epoch 173/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.8971 - mean_absolute_error: 0.0483 - val_loss: -4.9010 - val_mean_absolute_error: 0.0471
# Epoch 00173: val_loss did not improve from -4.91893
# Epoch 174/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.8970 - mean_absolute_error: 0.0502 - val_loss: -4.9013 - val_mean_absolute_error: 0.0451
#
# Epoch 00174: val_loss did not improve from -4.91893
# Epoch 175/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9059 - mean_absolute_error: 0.0399 - val_loss: -4.9055 - val_mean_absolute_error: 0.0392
#
# Epoch 00175: val_loss did not improve from -4.91893
# Epoch 176/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9057 - mean_absolute_error: 0.0344 - val_loss: -4.9056 - val_mean_absolute_error: 0.0361
#
# Epoch 00176: val_loss did not improve from -4.91893
# Epoch 177/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9086 - mean_absolute_error: 0.0314 - val_loss: -4.9115 - val_mean_absolute_error: 0.0282
#
# Epoch 00177: val_loss did not improve from -4.91893
# Epoch 178/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9112 - mean_absolute_error: 0.0272 - val_loss: -4.9104 - val_mean_absolute_error: 0.0293
#
# Epoch 00178: val_loss did not improve from -4.91893
# Epoch 179/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9112 - mean_absolute_error: 0.0273 - val_loss: -4.9147 - val_mean_absolute_error: 0.0242
#
# Epoch 00179: val_loss did not improve from -4.91893
# Epoch 180/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9097 - mean_absolute_error: 0.0305 - val_loss: -4.9134 - val_mean_absolute_error: 0.0297
#
# Epoch 00180: val_loss did not improve from -4.91893
# Epoch 181/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9114 - mean_absolute_error: 0.0293 - val_loss: -4.9114 - val_mean_absolute_error: 0.0307
#
# Epoch 00181: val_loss did not improve from -4.91893
# Epoch 182/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9110 - mean_absolute_error: 0.0305 - val_loss: -4.9138 - val_mean_absolute_error: 0.0272
#
# Epoch 00182: val_loss did not improve from -4.91893
# Epoch 183/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9137 - mean_absolute_error: 0.0266 - val_loss: -4.9118 - val_mean_absolute_error: 0.0349
#
# Epoch 00183: val_loss did not improve from -4.91893
# Epoch 184/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9103 - mean_absolute_error: 0.0334 - val_loss: -4.9115 - val_mean_absolute_error: 0.0316
#
# Epoch 00184: val_loss did not improve from -4.91893
# Epoch 185/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9051 - mean_absolute_error: 0.0388 - val_loss: -4.8873 - val_mean_absolute_error: 0.0625
#
# Epoch 00185: val_loss did not improve from -4.91893
# Epoch 186/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9052 - mean_absolute_error: 0.0457 - val_loss: -4.9114 - val_mean_absolute_error: 0.0371
#
# Epoch 00186: val_loss did not improve from -4.91893
# Epoch 187/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9062 - mean_absolute_error: 0.0399 - val_loss: -4.9100 - val_mean_absolute_error: 0.0372
#
# Epoch 00187: val_loss did not improve from -4.91893
# Epoch 188/1000
# 3501/3501 [==============================] - 0s 118us/step - loss: -4.9077 - mean_absolute_error: 0.0383 - val_loss: -4.9128 - val_mean_absolute_error: 0.0337
#
# Epoch 00188: val_loss did not improve from -4.91893
# Epoch 189/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9124 - mean_absolute_error: 0.0343 - val_loss: -4.9146 - val_mean_absolute_error: 0.0336
#
# Epoch 00189: val_loss did not improve from -4.91893
# Epoch 190/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9132 - mean_absolute_error: 0.0313 - val_loss: -4.9163 - val_mean_absolute_error: 0.0285
#
# Epoch 00190: val_loss did not improve from -4.91893
# Epoch 191/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9145 - mean_absolute_error: 0.0282 - val_loss: -4.9152 - val_mean_absolute_error: 0.0286
#
# Epoch 00191: val_loss did not improve from -4.91893
# Epoch 192/1000
# 3501/3501 [==============================] - 0s 110us/step - loss: -4.9150 - mean_absolute_error: 0.0270 - val_loss: -4.9168 - val_mean_absolute_error: 0.0263
#
# Epoch 00192: val_loss did not improve from -4.91893
# Epoch 193/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9157 - mean_absolute_error: 0.0252 - val_loss: -4.9178 - val_mean_absolute_error: 0.0242
#
# Epoch 00193: val_loss did not improve from -4.91893
# Epoch 194/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9168 - mean_absolute_error: 0.0230 - val_loss: -4.9177 - val_mean_absolute_error: 0.0228
#
# Epoch 00194: val_loss did not improve from -4.91893
# Epoch 195/1000
# 3501/3501 [==============================] - 1s 143us/step - loss: -4.9166 - mean_absolute_error: 0.0219 - val_loss: -4.9179 - val_mean_absolute_error: 0.0217
#
# Epoch 00195: val_loss did not improve from -4.91893
# Epoch 196/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.9164 - mean_absolute_error: 0.0213 - val_loss: -4.9172 - val_mean_absolute_error: 0.0215
#
# Epoch 00196: val_loss did not improve from -4.91893
# Epoch 197/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9157 - mean_absolute_error: 0.0222 - val_loss: -4.9180 - val_mean_absolute_error: 0.0202
#
# Epoch 00197: val_loss did not improve from -4.91893
# Epoch 198/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9118 - mean_absolute_error: 0.0276 - val_loss: -4.9158 - val_mean_absolute_error: 0.0254
#
# Epoch 00198: val_loss did not improve from -4.91893
# Epoch 199/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9106 - mean_absolute_error: 0.0297 - val_loss: -4.9128 - val_mean_absolute_error: 0.0294
#
# Epoch 00199: val_loss did not improve from -4.91893
# Epoch 200/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9143 - mean_absolute_error: 0.0259 - val_loss: -4.9160 - val_mean_absolute_error: 0.0246
#
# Epoch 00200: val_loss did not improve from -4.91893
# Epoch 201/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9121 - mean_absolute_error: 0.0287 - val_loss: -4.9143 - val_mean_absolute_error: 0.0261
#
# Epoch 00201: val_loss did not improve from -4.91893
# Epoch 202/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9140 - mean_absolute_error: 0.0249 - val_loss: -4.9173 - val_mean_absolute_error: 0.0228
#
# Epoch 00202: val_loss did not improve from -4.91893
# Epoch 203/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9167 - mean_absolute_error: 0.0214 - val_loss: -4.9183 - val_mean_absolute_error: 0.0212
#
# Epoch 00203: val_loss did not improve from -4.91893
# Epoch 204/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9158 - mean_absolute_error: 0.0228 - val_loss: -4.9157 - val_mean_absolute_error: 0.0245
#
# Epoch 00204: val_loss did not improve from -4.91893
# Epoch 205/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9107 - mean_absolute_error: 0.0322 - val_loss: -4.9161 - val_mean_absolute_error: 0.0268
#
# Epoch 00205: val_loss did not improve from -4.91893
# Epoch 206/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9134 - mean_absolute_error: 0.0273 - val_loss: -4.8957 - val_mean_absolute_error: 0.0432
#
# Epoch 00206: val_loss did not improve from -4.91893
# Epoch 207/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9091 - mean_absolute_error: 0.0312 - val_loss: -4.9042 - val_mean_absolute_error: 0.0391
#
# Epoch 00207: val_loss did not improve from -4.91893
# Epoch 208/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9084 - mean_absolute_error: 0.0373 - val_loss: -4.9153 - val_mean_absolute_error: 0.0294
#
# Epoch 00208: val_loss did not improve from -4.91893
# Epoch 209/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9128 - mean_absolute_error: 0.0301 - val_loss: -4.9170 - val_mean_absolute_error: 0.0243
#
# Epoch 00209: val_loss did not improve from -4.91893
# Epoch 210/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9155 - mean_absolute_error: 0.0247 - val_loss: -4.9168 - val_mean_absolute_error: 0.0246
#
# Epoch 00210: val_loss did not improve from -4.91893
# Epoch 211/1000
# 3501/3501 [==============================] - 0s 117us/step - loss: -4.9135 - mean_absolute_error: 0.0275 - val_loss: -4.9128 - val_mean_absolute_error: 0.0291
#
# Epoch 00211: val_loss did not improve from -4.91893
# Epoch 212/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.9103 - mean_absolute_error: 0.0311 - val_loss: -4.9165 - val_mean_absolute_error: 0.0246
#
# Epoch 00212: val_loss did not improve from -4.91893
# Epoch 213/1000
# 3501/3501 [==============================] - 0s 121us/step - loss: -4.9048 - mean_absolute_error: 0.0422 - val_loss: -4.9124 - val_mean_absolute_error: 0.0358
#
# Epoch 00213: val_loss did not improve from -4.91893
# Epoch 214/1000
# 3501/3501 [==============================] - 0s 125us/step - loss: -4.9120 - mean_absolute_error: 0.0309 - val_loss: -4.9130 - val_mean_absolute_error: 0.0260
#
# Epoch 00214: val_loss did not improve from -4.91893
# Epoch 215/1000
# 3501/3501 [==============================] - 0s 118us/step - loss: -4.9127 - mean_absolute_error: 0.0261 - val_loss: -4.9051 - val_mean_absolute_error: 0.0370
#
# Epoch 00215: val_loss did not improve from -4.91893
# Epoch 216/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9104 - mean_absolute_error: 0.0296 - val_loss: -4.9091 - val_mean_absolute_error: 0.0329
#
# Epoch 00216: val_loss did not improve from -4.91893
# Epoch 217/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9120 - mean_absolute_error: 0.0276 - val_loss: -4.9150 - val_mean_absolute_error: 0.0261
#
# Epoch 00217: val_loss did not improve from -4.91893
# Epoch 218/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9154 - mean_absolute_error: 0.0236 - val_loss: -4.9179 - val_mean_absolute_error: 0.0211
#
# Epoch 00218: val_loss did not improve from -4.91893
# Epoch 219/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9120 - mean_absolute_error: 0.0284 - val_loss: -4.9085 - val_mean_absolute_error: 0.0383
#
# Epoch 00219: val_loss did not improve from -4.91893
# Epoch 220/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9139 - mean_absolute_error: 0.0281 - val_loss: -4.9161 - val_mean_absolute_error: 0.0249
#
# Epoch 00220: val_loss did not improve from -4.91893
# Epoch 221/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9119 - mean_absolute_error: 0.0296 - val_loss: -4.9133 - val_mean_absolute_error: 0.0311
#
# Epoch 00221: val_loss did not improve from -4.91893
# Epoch 222/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9085 - mean_absolute_error: 0.0339 - val_loss: -4.9102 - val_mean_absolute_error: 0.0347
#
# Epoch 00222: val_loss did not improve from -4.91893
# Epoch 223/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9117 - mean_absolute_error: 0.0284 - val_loss: -4.9127 - val_mean_absolute_error: 0.0274
#
# Epoch 00223: val_loss did not improve from -4.91893
# Epoch 224/1000
# 3501/3501 [==============================] - 0s 102us/step - loss: -4.9127 - mean_absolute_error: 0.0252 - val_loss: -4.9106 - val_mean_absolute_error: 0.0304
#
# Epoch 00224: val_loss did not improve from -4.91893
# Epoch 225/1000
# 3501/3501 [==============================] - 0s 103us/step - loss: -4.9046 - mean_absolute_error: 0.0375 - val_loss: -4.9128 - val_mean_absolute_error: 0.0324
#
# Epoch 00225: val_loss did not improve from -4.91893
# Epoch 226/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9125 - mean_absolute_error: 0.0302 - val_loss: -4.9129 - val_mean_absolute_error: 0.0309
#
# Epoch 00226: val_loss did not improve from -4.91893
# Epoch 227/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9071 - mean_absolute_error: 0.0374 - val_loss: -4.9127 - val_mean_absolute_error: 0.0343
#
# Epoch 00227: val_loss did not improve from -4.91893
# Epoch 228/1000
# 3501/3501 [==============================] - 0s 113us/step - loss: -4.9077 - mean_absolute_error: 0.0394 - val_loss: -4.9055 - val_mean_absolute_error: 0.0444
#
# Epoch 00228: val_loss did not improve from -4.91893
# Epoch 229/1000
# 3501/3501 [==============================] - 0s 106us/step - loss: -4.9083 - mean_absolute_error: 0.0385 - val_loss: -4.9120 - val_mean_absolute_error: 0.0353
#
# Epoch 00229: val_loss did not improve from -4.91893
# Epoch 230/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9027 - mean_absolute_error: 0.0442 - val_loss: -4.9030 - val_mean_absolute_error: 0.0459
#
# Epoch 00230: val_loss did not improve from -4.91893
# Epoch 231/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9076 - mean_absolute_error: 0.0402 - val_loss: -4.9082 - val_mean_absolute_error: 0.0385
#
# Epoch 00231: val_loss did not improve from -4.91893
# Epoch 232/1000
# 3501/3501 [==============================] - 0s 110us/step - loss: -4.9079 - mean_absolute_error: 0.0375 - val_loss: -4.9094 - val_mean_absolute_error: 0.0379
#
# Epoch 00232: val_loss did not improve from -4.91893
# Epoch 233/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9094 - mean_absolute_error: 0.0352 - val_loss: -4.9133 - val_mean_absolute_error: 0.0324
#
# Epoch 00233: val_loss did not improve from -4.91893
# Epoch 234/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9106 - mean_absolute_error: 0.0364 - val_loss: -4.9152 - val_mean_absolute_error: 0.0310
#
# Epoch 00234: val_loss did not improve from -4.91893
# Epoch 235/1000
# 3501/3501 [==============================] - 0s 112us/step - loss: -4.9121 - mean_absolute_error: 0.0324 - val_loss: -4.9129 - val_mean_absolute_error: 0.0309
#
# Epoch 00235: val_loss did not improve from -4.91893
# Epoch 236/1000
# 3501/3501 [==============================] - 0s 116us/step - loss: -4.8877 - mean_absolute_error: 0.0529 - val_loss: -4.8842 - val_mean_absolute_error: 0.0639
#
# Epoch 00236: val_loss did not improve from -4.91893
# Epoch 237/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.8927 - mean_absolute_error: 0.0561 - val_loss: -4.8915 - val_mean_absolute_error: 0.0586
#
# Epoch 00237: val_loss did not improve from -4.91893
# Epoch 238/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.8992 - mean_absolute_error: 0.0503 - val_loss: -4.9043 - val_mean_absolute_error: 0.0479
#
# Epoch 00238: val_loss did not improve from -4.91893
# Epoch 239/1000
# 3501/3501 [==============================] - 0s 126us/step - loss: -4.9017 - mean_absolute_error: 0.0500 - val_loss: -4.8874 - val_mean_absolute_error: 0.0649
#
# Epoch 00239: val_loss did not improve from -4.91893
# Epoch 240/1000
# 3501/3501 [==============================] - 0s 128us/step - loss: -4.8939 - mean_absolute_error: 0.0561 - val_loss: -4.9043 - val_mean_absolute_error: 0.0478
#
# Epoch 00240: val_loss did not improve from -4.91893
# Epoch 241/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.9080 - mean_absolute_error: 0.0428 - val_loss: -4.9090 - val_mean_absolute_error: 0.0409
#
# Epoch 00241: val_loss did not improve from -4.91893
# Epoch 242/1000
# 3501/3501 [==============================] - 0s 119us/step - loss: -4.9109 - mean_absolute_error: 0.0375 - val_loss: -4.9138 - val_mean_absolute_error: 0.0355
#
# Epoch 00242: val_loss did not improve from -4.91893
# Epoch 243/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9124 - mean_absolute_error: 0.0343 - val_loss: -4.9148 - val_mean_absolute_error: 0.0329
#
# Epoch 00243: val_loss did not improve from -4.91893
# Epoch 244/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.9135 - mean_absolute_error: 0.0314 - val_loss: -4.9153 - val_mean_absolute_error: 0.0307
#
# Epoch 00244: val_loss did not improve from -4.91893
# Epoch 245/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.9143 - mean_absolute_error: 0.0297 - val_loss: -4.9157 - val_mean_absolute_error: 0.0294
#
# Epoch 00245: val_loss did not improve from -4.91893
# Epoch 246/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9139 - mean_absolute_error: 0.0287 - val_loss: -4.9151 - val_mean_absolute_error: 0.0288
#
# Epoch 00246: val_loss did not improve from -4.91893
# Epoch 247/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9101 - mean_absolute_error: 0.0334 - val_loss: -4.9121 - val_mean_absolute_error: 0.0323
#
# Epoch 00247: val_loss did not improve from -4.91893
# Epoch 248/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9130 - mean_absolute_error: 0.0302 - val_loss: -4.9070 - val_mean_absolute_error: 0.0382
#
# Epoch 00248: val_loss did not improve from -4.91893
# Epoch 249/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9074 - mean_absolute_error: 0.0370 - val_loss: -4.9081 - val_mean_absolute_error: 0.0401
#
# Epoch 00249: val_loss did not improve from -4.91893
# Epoch 250/1000
# 3501/3501 [==============================] - 0s 104us/step - loss: -4.9082 - mean_absolute_error: 0.0380 - val_loss: -4.9119 - val_mean_absolute_error: 0.0357
#
# Epoch 00250: val_loss did not improve from -4.91893
# Epoch 251/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9111 - mean_absolute_error: 0.0344 - val_loss: -4.9055 - val_mean_absolute_error: 0.0395
#
# Epoch 00251: val_loss did not improve from -4.91893
# Epoch 252/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9084 - mean_absolute_error: 0.0344 - val_loss: -4.9118 - val_mean_absolute_error: 0.0310
#
# Epoch 00252: val_loss did not improve from -4.91893
# Epoch 253/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9063 - mean_absolute_error: 0.0346 - val_loss: -4.9027 - val_mean_absolute_error: 0.0403
#
# Epoch 00253: val_loss did not improve from -4.91893
# Epoch 254/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9022 - mean_absolute_error: 0.0419 - val_loss: -4.8963 - val_mean_absolute_error: 0.0549
#
# Epoch 00254: val_loss did not improve from -4.91893
# Epoch 255/1000
# 3501/3501 [==============================] - 0s 109us/step - loss: -4.9018 - mean_absolute_error: 0.0440 - val_loss: -4.9039 - val_mean_absolute_error: 0.0410
#
# Epoch 00255: val_loss did not improve from -4.91893
# Epoch 256/1000
# 3501/3501 [==============================] - 0s 111us/step - loss: -4.9041 - mean_absolute_error: 0.0388 - val_loss: -4.9028 - val_mean_absolute_error: 0.0417
#
# Epoch 00256: val_loss did not improve from -4.91893
# Epoch 257/1000
# 3501/3501 [==============================] - 0s 107us/step - loss: -4.9058 - mean_absolute_error: 0.0369 - val_loss: -4.9118 - val_mean_absolute_error: 0.0321
#
# Epoch 00257: val_loss did not improve from -4.91893
# Epoch 258/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9056 - mean_absolute_error: 0.0363 - val_loss: -4.8930 - val_mean_absolute_error: 0.0529
#
# Epoch 00258: val_loss did not improve from -4.91893
# Epoch 259/1000
# 3501/3501 [==============================] - 0s 105us/step - loss: -4.9016 - mean_absolute_error: 0.0470 - val_loss: -4.9071 - val_mean_absolute_error: 0.0442
#
# Epoch 00259: val_loss did not improve from -4.91893
# Epoch 260/1000
# 3501/3501 [==============================] - 0s 108us/step - loss: -4.9047 - mean_absolute_error: 0.0430 - val_loss: -4.9055 - val_mean_absolute_error: 0.0411
#
# Epoch 00260: val_loss did not improve from -4.91893
# Epoch 261/1000
# 3501/3501 [==============================] - 0s 114us/step - loss: -4.9063 - mean_absolute_error: 0.0388 - val_loss: -4.9031 - val_mean_absolute_error: 0.0400
#
# Epoch 00261: val_loss did not improve from -4.91893
# Epoch 262/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.9022 - mean_absolute_error: 0.0399 - val_loss: -4.9045 - val_mean_absolute_error: 0.0376
#
# Epoch 00262: val_loss did not improve from -4.91893
# Epoch 263/1000
# 3501/3501 [==============================] - 0s 127us/step - loss: -4.9024 - mean_absolute_error: 0.0410 - val_loss: -4.9066 - val_mean_absolute_error: 0.0398
#
# Epoch 00263: val_loss did not improve from -4.91893
# Epoch 264/1000
# 3501/3501 [==============================] - 0s 120us/step - loss: -4.9090 - mean_absolute_error: 0.0328 - val_loss: -4.9114 - val_mean_absolute_error: 0.0302
#
# Epoch 00264: val_loss did not improve from -4.91893
# Epoch 265/1000
# 3501/3501 [==============================] - 0s 123us/step - loss: -4.9114 - mean_absolute_error: 0.0287 - val_loss: -4.9136 - val_mean_absolute_error: 0.0277
#
# Epoch 00265: val_loss did not improve from -4.91893
# Epoch 266/1000
# 3501/3501 [==============================] - 0s 115us/step - loss: -4.9069 - mean_absolute_error: 0.0351 - val_loss: -4.9067 - val_mean_absolute_error: 0.0402
#
# Epoch 00266: val_loss did not improve from -4.91893
# Epoch 00266: early stopping

# %%
# QC training results
plt.plot(results.history['val_mean_absolute_error'], label='val')
plt.plot(results.history['mean_absolute_error'], label='train')
plt.show()

plt.plot(results.history['val_loss'], label='val')
plt.plot(results.history['loss'], label='train')
plt.title('loss')
plt.legend()
plt.show()

# %% [markdown]
# ## QC encoding

# %%
encoded_sin = encoder.predict(x_test)
decoded_sin = decoder.predict(encoded_sin)

# %%
plt.plot(t,decoded_sin[np.random.randint(0,n_test-1),:])
plt.show()

# %% [markdown]
# # Showcase denoising properties of autoencoder
# ---

# %%
# specific sine wave index of interest
sin_index = np.random.randint(0,n_test-1)

# %%
# effects of noise on input
for i in range(4):
    plt.figure(figsize=(7,3))
    sin_noisy = x_test + np.random.randn(n_test,nt)*i
    encoded_sin = encoder.predict(sin_noisy)
    decoded_sin = decoder.predict(encoded_sin)
    
    plt.plot(t, sin_noisy[sin_index,:], label='noisy input')
    plt.plot(t,decoded_sin[sin_index,:], label='denoised')
    plt.plot(t,x_test[sin_index,:], 'k', lw=6, alpha=0.5, label='no noise')
    plt.title('noise $\sigma$ = %2.1f'%i)
    plt.legend()
    plt.show()
